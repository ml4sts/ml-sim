# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
from mlsim import sp_plot
import seaborn as sns
sns.set(font_scale=4, rc={"lines.linewidth": 5})

# %%
df = pd.read_csv('../../detect_simpsons_paradox_dev/data/wages_rank_gender_regression_time2.csv')

# %%
df.head()
# Out:
#      pay  year department gender
# 0  22.63   0.0    Support      F
# 1  24.74   0.0    Support      F
# 2  21.16   0.0    Support      M
# 3  21.11   0.0    Support      M
# 4  19.39   0.0    Support      M

# %%
sp_plot(df,'year','pay','department',domain_range=[-2,53,10,55],aggplot=False,x_jitter=1.85,height=20,legend=False)

# %%
sp_plot(df,'year','pay','department',domain_range=[-2,53,10,55],x_jitter=1.85,height=20,legend=False)
